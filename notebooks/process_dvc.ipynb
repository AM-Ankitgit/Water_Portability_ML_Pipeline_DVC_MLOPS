# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # store the data versioning in local folder
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dvc push

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## for running the dvc pipeline with experiment tracking
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## we experiment multiple values at time like this
#
# ![image.png](attachment:image.png)

# %% [markdown]
# run above experiment
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### remove the specific experiment
#
# ![image.png](attachment:image.png)

# %% [markdown]
# out of all this experiment
#
# select one experiment which is beset for your case
#
# ![image.png](attachment:image.png)
