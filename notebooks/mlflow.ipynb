# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
we can use auto log

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # we can use auto logging use below function
# instead of manual code
#
# ![image.png](attachment:image.png)
